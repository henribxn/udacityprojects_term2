# %%
from sqlalchemy import create_engine
import pandas as pd
import os
import joblib

# %%
def tokenize(text):
    
    # Normalise by setting to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)
    
    # Create tokens 
    tokens = word_tokenize(text)
    
    # Remove stopwords
    tokens = [w for w in tokens if w not in stopwords.words("english")]
    
    # Lemmatise words
    clean_tokens = [WordNetLemmatizer().lemmatize(w) for w in tokens]

    return clean_tokens

# %%
# Create database
! python data/process_data.py "data/disaster_messages.csv" "data/disaster_categories.csv" "data/DisasterDB.db"
# Out:
# Loading data...
#     MESSAGES: data/disaster_messages.csv
#     CATEGORIES: data/disaster_categories.csv
# Cleaning data...
# Saving data...
#     DATABASE: data/DisasterDB.db
# Cleaned data saved to database!

# %%
# Train model
! python models/train_classifier.py "data/DisasterDB.db" "models/model_classifier.pkl"
# Out:
# [nltk_data] Downloading package punkt to /Users/boubou/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/boubou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/boubou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Loading data...
#     DATABASE: data/DisasterDB.db
# Building model...
# Training model...
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Evaluating model...
# Column 0: related
#                 precision    recall  f1-score   support
#
#     is_related       0.74      0.42      0.53      1230
# is_not_related       0.84      0.95      0.89      4014
#
#      micro avg       0.83      0.83      0.83      5244
#      macro avg       0.79      0.69      0.71      5244
#   weighted avg       0.82      0.83      0.81      5244
#
# Column 1: request
#                 precision    recall  f1-score   support
#
#     is_request       0.91      0.98      0.94      4341
# is_not_request       0.83      0.54      0.66       903
#
#      micro avg       0.90      0.90      0.90      5244
#      macro avg       0.87      0.76      0.80      5244
#   weighted avg       0.90      0.90      0.89      5244
#
# Column 2: offer
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#     is_offer       1.00      1.00      1.00      5226
# is_not_offer       0.00      0.00      0.00        18
#
#    micro avg       1.00      1.00      1.00      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      1.00      0.99      5244
#
# Column 3: aid_related
#                     precision    recall  f1-score   support
#
#     is_aid_related       0.80      0.86      0.83      3105
# is_not_aid_related       0.77      0.69      0.73      2139
#
#          micro avg       0.79      0.79      0.79      5244
#          macro avg       0.78      0.77      0.78      5244
#       weighted avg       0.79      0.79      0.79      5244
#
# Column 4: medical_help
#                      precision    recall  f1-score   support
#
#     is_medical_help       0.93      0.99      0.96      4846
# is_not_medical_help       0.59      0.15      0.24       398
#
#           micro avg       0.93      0.93      0.93      5244
#           macro avg       0.76      0.57      0.60      5244
#        weighted avg       0.91      0.93      0.91      5244
#
# Column 5: medical_products
#                          precision    recall  f1-score   support
#
#     is_medical_products       0.96      1.00      0.98      4985
# is_not_medical_products       0.79      0.21      0.33       259
#
#               micro avg       0.96      0.96      0.96      5244
#               macro avg       0.87      0.60      0.66      5244
#            weighted avg       0.95      0.96      0.95      5244
#
# Column 6: search_and_rescue
#                           precision    recall  f1-score   support
#
#     is_search_and_rescue       0.97      1.00      0.99      5099
# is_not_search_and_rescue       0.75      0.02      0.04       145
#
#                micro avg       0.97      0.97      0.97      5244
#                macro avg       0.86      0.51      0.51      5244
#             weighted avg       0.97      0.97      0.96      5244
#
# Column 7: security
#                  precision    recall  f1-score   support
#
#     is_security       0.98      1.00      0.99      5141
# is_not_security       0.00      0.00      0.00       103
#
#       micro avg       0.98      0.98      0.98      5244
#       macro avg       0.49      0.50      0.50      5244
#    weighted avg       0.96      0.98      0.97      5244
#
# Column 8: military
#                  precision    recall  f1-score   support
#
#     is_military       0.97      1.00      0.98      5072
# is_not_military       0.71      0.12      0.20       172
#
#       micro avg       0.97      0.97      0.97      5244
#       macro avg       0.84      0.56      0.59      5244
#    weighted avg       0.96      0.97      0.96      5244
#
# Column 9: water
#               precision    recall  f1-score   support
#
#     is_water       0.97      0.99      0.98      4920
# is_not_water       0.78      0.52      0.63       324
#
#    micro avg       0.96      0.96      0.96      5244
#    macro avg       0.88      0.76      0.80      5244
# weighted avg       0.96      0.96      0.96      5244
#
# Column 10: food
#               precision    recall  f1-score   support
#
#      is_food       0.95      0.99      0.97      4670
#  is_not_food       0.85      0.57      0.68       574
#
#    micro avg       0.94      0.94      0.94      5244
#    macro avg       0.90      0.78      0.83      5244
# weighted avg       0.94      0.94      0.94      5244
#
# Column 11: shelter
#                 precision    recall  f1-score   support
#
#     is_shelter       0.95      0.99      0.97      4785
# is_not_shelter       0.83      0.44      0.58       459
#
#      micro avg       0.94      0.94      0.94      5244
#      macro avg       0.89      0.72      0.77      5244
#   weighted avg       0.94      0.94      0.94      5244
#
# Column 12: clothing
#                  precision    recall  f1-score   support
#
#     is_clothing       0.99      1.00      0.99      5150
# is_not_clothing       0.76      0.17      0.28        94
#
#       micro avg       0.98      0.98      0.98      5244
#       macro avg       0.87      0.58      0.64      5244
#    weighted avg       0.98      0.98      0.98      5244
#
# Column 13: money
#               precision    recall  f1-score   support
#
#     is_money       0.98      1.00      0.99      5109
# is_not_money       0.69      0.07      0.12       135
#
#    micro avg       0.98      0.98      0.98      5244
#    macro avg       0.83      0.53      0.55      5244
# weighted avg       0.97      0.98      0.97      5244
#
# Column 14: missing_people
#                        precision    recall  f1-score   support
#
#     is_missing_people       0.99      1.00      0.99      5175
# is_not_missing_people       1.00      0.01      0.03        69
#
#             micro avg       0.99      0.99      0.99      5244
#             macro avg       0.99      0.51      0.51      5244
#          weighted avg       0.99      0.99      0.98      5244
#
# Column 15: refugees
#                  precision    recall  f1-score   support
#
#     is_refugees       0.96      1.00      0.98      5047
# is_not_refugees       0.71      0.06      0.11       197
#
#       micro avg       0.96      0.96      0.96      5244
#       macro avg       0.84      0.53      0.55      5244
#    weighted avg       0.95      0.96      0.95      5244
#
# Column 16: death
#               precision    recall  f1-score   support
#
#     is_death       0.97      1.00      0.98      5009
# is_not_death       0.87      0.23      0.36       235
#
#    micro avg       0.96      0.96      0.96      5244
#    macro avg       0.92      0.61      0.67      5244
# weighted avg       0.96      0.96      0.95      5244
#
# Column 17: other_aid
#                   precision    recall  f1-score   support
#
#     is_other_aid       0.88      0.99      0.93      4551
# is_not_other_aid       0.59      0.12      0.20       693
#
#        micro avg       0.87      0.87      0.87      5244
#        macro avg       0.73      0.55      0.57      5244
#     weighted avg       0.84      0.87      0.83      5244
#
# Column 18: infrastructure_related
#                                precision    recall  f1-score   support
#
#     is_infrastructure_related       0.94      1.00      0.97      4895
# is_not_infrastructure_related       0.48      0.03      0.05       349
#
#                     micro avg       0.93      0.93      0.93      5244
#                     macro avg       0.71      0.51      0.51      5244
#                  weighted avg       0.90      0.93      0.90      5244
#
# Column 19: transport
#                   precision    recall  f1-score   support
#
#     is_transport       0.96      1.00      0.98      5010
# is_not_transport       0.73      0.13      0.22       234
#
#        micro avg       0.96      0.96      0.96      5244
#        macro avg       0.85      0.56      0.60      5244
#     weighted avg       0.95      0.96      0.95      5244
#
# Column 20: buildings
#                   precision    recall  f1-score   support
#
#     is_buildings       0.96      1.00      0.98      4963
# is_not_buildings       0.78      0.17      0.28       281
#
#        micro avg       0.95      0.95      0.95      5244
#        macro avg       0.87      0.59      0.63      5244
#     weighted avg       0.95      0.95      0.94      5244
#
# Column 21: electricity
#                     precision    recall  f1-score   support
#
#     is_electricity       0.98      1.00      0.99      5151
# is_not_electricity       0.50      0.10      0.16        93
#
#          micro avg       0.98      0.98      0.98      5244
#          macro avg       0.74      0.55      0.58      5244
#       weighted avg       0.98      0.98      0.98      5244
#
# Column 22: tools
#               precision    recall  f1-score   support
#
#     is_tools       0.99      1.00      1.00      5210
# is_not_tools       0.00      0.00      0.00        34
#
#    micro avg       0.99      0.99      0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
# Column 23: hospitals
#                   precision    recall  f1-score   support
#
#     is_hospitals       0.99      1.00      1.00      5201
# is_not_hospitals       0.33      0.02      0.04        43
#
#        micro avg       0.99      0.99      0.99      5244
#        macro avg       0.66      0.51      0.52      5244
#     weighted avg       0.99      0.99      0.99      5244
#
# Column 24: shops
#               precision    recall  f1-score   support
#
#     is_shops       0.99      1.00      1.00      5217
# is_not_shops       0.00      0.00      0.00        27
#
#    micro avg       0.99      0.99      0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
# Column 25: aid_centers
#                     precision    recall  f1-score   support
#
#     is_aid_centers       0.99      1.00      0.99      5170
# is_not_aid_centers       0.00      0.00      0.00        74
#
#          micro avg       0.99      0.99      0.99      5244
#          macro avg       0.49      0.50      0.50      5244
#       weighted avg       0.97      0.99      0.98      5244
#
# Column 26: other_infrastructure
#                              precision    recall  f1-score   support
#
#     is_other_infrastructure       0.95      1.00      0.98      5002
# is_not_other_infrastructure       0.14      0.00      0.01       242
#
#                   micro avg       0.95      0.95      0.95      5244
#                   macro avg       0.55      0.50      0.49      5244
#                weighted avg       0.92      0.95      0.93      5244
#
# Column 27: weather_related
#                         precision    recall  f1-score   support
#
#     is_weather_related       0.88      0.96      0.92      3798
# is_not_weather_related       0.88      0.67      0.76      1446
#
#              micro avg       0.88      0.88      0.88      5244
#              macro avg       0.88      0.82      0.84      5244
#           weighted avg       0.88      0.88      0.88      5244
#
# Column 28: floods
#                precision    recall  f1-score   support
#
#     is_floods       0.95      1.00      0.97      4817
# is_not_floods       0.90      0.44      0.59       427
#
#     micro avg       0.95      0.95      0.95      5244
#     macro avg       0.92      0.72      0.78      5244
#  weighted avg       0.95      0.95      0.94      5244
#
# Column 29: storm
#               precision    recall  f1-score   support
#
#     is_storm       0.94      0.98      0.96      4726
# is_not_storm       0.75      0.43      0.55       518
#
#    micro avg       0.93      0.93      0.93      5244
#    macro avg       0.85      0.71      0.75      5244
# weighted avg       0.92      0.93      0.92      5244
#
# Column 30: fire
#               precision    recall  f1-score   support
#
#      is_fire       0.99      1.00      0.99      5189
#  is_not_fire       0.67      0.04      0.07        55
#
#    micro avg       0.99      0.99      0.99      5244
#    macro avg       0.83      0.52      0.53      5244
# weighted avg       0.99      0.99      0.99      5244
#
# Column 31: earthquake
#                    precision    recall  f1-score   support
#
#     is_earthquake       0.97      0.99      0.98      4773
# is_not_earthquake       0.90      0.69      0.78       471
#
#         micro avg       0.96      0.96      0.96      5244
#         macro avg       0.93      0.84      0.88      5244
#      weighted avg       0.96      0.96      0.96      5244
#
# Column 32: cold
#               precision    recall  f1-score   support
#
#      is_cold       0.98      1.00      0.99      5135
#  is_not_cold       0.88      0.13      0.22       109
#
#    micro avg       0.98      0.98      0.98      5244
#    macro avg       0.93      0.56      0.61      5244
# weighted avg       0.98      0.98      0.97      5244
#
# Column 33: other_weather
#                       precision    recall  f1-score   support
#
#     is_other_weather       0.95      1.00      0.97      4977
# is_not_other_weather       0.61      0.04      0.08       267
#
#            micro avg       0.95      0.95      0.95      5244
#            macro avg       0.78      0.52      0.53      5244
#         weighted avg       0.93      0.95      0.93      5244
#
# Column 34: direct_report
#                       precision    recall  f1-score   support
#
#     is_direct_report       0.88      0.96      0.92      4261
# is_not_direct_report       0.74      0.45      0.56       983
#
#            micro avg       0.87      0.87      0.87      5244
#            macro avg       0.81      0.71      0.74      5244
#         weighted avg       0.86      0.87      0.85      5244
#
# Saving model...
#     MODEL: models/model_classifier.pkl
# Trained model saved!

# %%
engine = create_engine('sqlite:///data/DisasterDB.db')
df = pd.read_sql_table('messages', engine)

# %%
model = joblib.load("models/model_classifier.pkl")
